# %%
using StatisticalRethinking
using CairoMakie
using Turing
using Makie

# %% [markdown]
# #### Code 4.37

# %%
d = CSV.File(joinpath("data","Howell1.csv")) |> DataFrame;
d2 = d[d.age .>= 18,:]
Makie.plot(d2.height,d2.weight, axis = (xlabel="height",ylabel="weight"), color=:dodgerblue4)
# Out:
# FigureAxisPlot()
